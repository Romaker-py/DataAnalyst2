# %% [markdown]
# #### 从数据库导入数据

# %%
import pymysql.cursors
import pandas as pd

db = pymysql.connect(host='localhost',user='root',password='root',db='lagou',charset='utf8',cursorclass=pymysql.cursors.DictCursor)
cursor = db.cursor()
sql = 'SELECT * FROM dataset;'
cursor.execute(sql)
result = cursor.fetchall()
df = pd.DataFrame(list(result))
db.close()

df
# Out:
#     jobNature companySize workYear education industryField thirdType  \
# 0          全职   500-2000人     1-3年        本科            旅游      数据分析
# 1          全职   500-2000人     3-5年        本科    消费生活,移动互联网        商业
# 2          全职     2000人以上    5-10年        本科            金融        建模
# 3          全职     2000人以上     1-3年        本科            金融    Hadoop
# 4          全职     2000人以上     1-3年        大专      移动互联网,游戏      数据分析
# ..        ...         ...      ...       ...           ...       ...
# 270        全职     2000人以上     3-5年        本科            社交      产品经理
# 271        全职     2000人以上     3-5年        本科            社交      数据挖掘
# 272        全职     2000人以上     3-5年        本科            社交      数据分析
# 273        全职     2000人以上     1-3年        本科            金融      数据分析
# 274        全职     2000人以上     3-5年        本科            金融      数据运营
#
#      salaryMin  salaryMax  nameUnfit positionId  ... financeStage  firstType  \
# 0           18         35          0    6112946  ...        D轮及以上  开发|测试|运维类
# 1           15         25          0    6229664  ...           C轮  产品|需求|项目类
# 2           15         30          0    6853427  ...         上市公司  开发|测试|运维类
# 3           20         30          0    6692363  ...        不需要融资  开发|测试|运维类
# 4            8         10          0    6835783  ...        不需要融资  产品|需求|项目类
# ..         ...        ...        ...        ...  ...          ...        ...
# 270         15         25          1    5276304  ...         上市公司  产品|需求|项目类
# 271         18         35          0    6842800  ...         上市公司  开发|测试|运维类
# 272         20         40          0    5250466  ...         上市公司  产品|需求|项目类
# 273         20         30          0    6391267  ...          未融资  开发|测试|运维类
# 274         20         30          0    6823600  ...          未融资  运营|编辑|客服类
#
#     secondType district   salary resumeProcessRate resumeProcessDay  score  \
# 0         数据开发      福田区  18k-35k               100                1    199
# 1         数据分析      南山区  15k-25k               100                1    179
# 2         数据开发      福田区  15k-30k               100                1    130
# 3         数据开发      南山区  20k-30k               100                2     89
# 4         数据分析      南山区   8k-10k                 0                1     69
# ..         ...      ...      ...               ...              ...    ...
# 270       产品经理      南山区  15k-25k               100                1     10
# 271       数据开发      南山区  18k-35k               100                1     10
# 272       数据分析      南山区  20k-40k               100                1     10
# 273       数据开发      南山区  20k-30k                15                1      4
# 274         运营      南山区  20k-30k                15                1      4
#
#      famousCompany  isFocus
# 0                0        1
# 1                0        1
# 2                1        0
# 3                0        0
# 4                0        0
# ..             ...      ...
# 270              1        0
# 271              1        1
# 272              1        1
# 273              1        0
# 274              1        0
#
# [275 rows x 22 columns]

# %% [markdown]
# #### 拆分训练集和测试集

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,:-1]
X = pd.get_dummies(X).values
y = df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_names = pd.get_dummies(df.iloc[:,:-1]).columns
X_names
# Out:
# Index(['salaryMin', 'salaryMax', 'nameUnfit', 'resumeProcessRate',
#        'resumeProcessDay', 'score', 'famousCompany', 'jobNature_全职',
#        'jobNature_兼职', 'jobNature_实习',
#        ...
#        'salary_7k-13k', 'salary_7k-14k', 'salary_8k-10k', 'salary_8k-11k',
#        'salary_8k-12k', 'salary_8k-13k', 'salary_8k-15k', 'salary_8k-16k',
#        'salary_9k-12k', 'salary_9k-14k'],
#       dtype='object', length=687)

# %% [markdown]
# #### 网格搜索（含交叉验证）——找出最优参数

# %%
# ?GridSearchCV

# %%
# ?RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

rfc = RandomForestClassifier()
parameters = {
    'random_state':[0],
    'criterion':['gini','entropy'],
    'n_estimators':[10,50,100],
    'min_samples_leaf':[3,4,5,6,7],
    'max_depth':[7,8,9,10]
}
scorings = ['recall','roc_auc']
for scoring in scorings:
    print('===========================================================================')
    print('此次调参的scoring为：%s' % scoring)
    print()
    clf = GridSearchCV(rfc, parameters, scoring=scoring, cv=10)
    clf.fit(X_train, y_train)
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    params = clf.cv_results_['params']
    print('【交叉验证】过程如下：')
    for mean, std, param in zip(means, stds, params):
        print('%s得分为 %0.3f(+-%0.3f)时，参数为：%r' % (scoring, mean, std * 2, param))
    print()
    print('【训练集】最佳参数为：%r' % clf.best_params_)
    print('【训练集】最佳参数得分为：%0.3f' % clf.best_score_)
    print()
    print('【测试集】%s得分为：%0.3f' % (scoring, clf.score(X_test, y_test)))    # 直接获取测试集的得分
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    reports = classification_report(y_true, y_pred)
    print('【测试集中实际值与预测值对比】模型报告如下：')
    print(reports)
# Out:
# ===========================================================================
# 此次调参的scoring为：recall
# C:\Users\romak\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 【交叉验证】过程如下：
# recall得分为 0.020(+-0.119)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.084(+-0.277)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.044(+-0.179)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.086(+-0.308)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.084(+-0.277)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.021(+-0.122)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.089(+-0.438)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.084(+-0.209)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.021(+-0.122)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.110(+-0.438)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.105(+-0.279)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.021(+-0.122)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.021(+-0.122)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.066(+-0.211)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.084(+-0.209)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.043(+-0.177)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.110(+-0.316)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.084(+-0.209)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.043(+-0.177)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.153(+-0.431)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.105(+-0.211)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.085(+-0.220)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.023(+-0.145)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.110(+-0.316)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.063(+-0.198)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.084(+-0.209)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.066(+-0.211)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 100, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 10, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 50, 'random_state': 0}
# recall得分为 0.000(+-0.000)时，参数为：{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 100, 'random_state': 0}
#
# 【训练集】最佳参数为：{'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# 【训练集】最佳参数得分为：0.153
#
# 【测试集】recall得分为：0.083
#
# 【测试集中实际值与预测值对比】模型报告如下：
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        67
#            1       1.00      0.08      0.15        24
#
#     accuracy                           0.76        91
#    macro avg       0.88      0.54      0.51        91
# weighted avg       0.82      0.76      0.67        91
#
# ===========================================================================
# 此次调参的scoring为：roc_auc
# 【交叉验证】过程如下：
# roc_auc得分为 0.884(+-0.151)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 10, 'random_state': 0}
# roc_auc得分为 0.909(+-0.114)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 50, 'random_state': 0}
# roc_auc得分为 0.918(+-0.124)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 3, 'n_estimators': 100, 'random_state': 0}
# roc_auc得分为 0.901(+-0.172)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 10, 'random_state': 0}
# roc_auc得分为 0.885(+-0.146)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 50, 'random_state': 0}
# roc_auc得分为 0.899(+-0.152)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4, 'n_estimators': 100, 'random_state': 0}
# roc_auc得分为 0.859(+-0.173)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 10, 'random_state': 0}
# roc_auc得分为 0.892(+-0.161)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 50, 'random_state': 0}
# roc_auc得分为 0.893(+-0.172)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'n_estimators': 100, 'random_state': 0}
# roc_auc得分为 0.782(+-0.170)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0}
# roc_auc得分为 0.893(+-0.171)时，参数为：{'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'n_estimators': 50, 'random_state': 0}
# roc_auc得分为 0