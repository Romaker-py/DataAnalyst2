# %% [markdown]
# #### 先从MySQL导入数据到DataFrame：

# %%
import pymysql.cursors
import pandas as pd
import numpy as np

db = pymysql.connect(host='localhost',user='root',password='root',db='python',charset='utf8',cursorclass=pymysql.cursors.DictCursor)
cursor = db.cursor()
sql = 'SELECT * FROM car_loss;'
cursor.execute(sql)
result = cursor.fetchall()
df = pd.DataFrame(list(result))
db.close()

df.head(20)
# Out:
#     EngSize  Age Gender Marital  exp Owner  vAge Garage AntiTFD import   Loss
# 0       2.0   56      男           20    公司    10      有   有防盗装置     进口    0.0
# 1       1.8   41      男           20    公司     9      有   无防盗装置     国产    0.0
# 2       2.0   44      男           20    公司     8      有   有防盗装置     国产    0.0
# 3       1.6   56      男           20    公司     7      有   有防盗装置     国产    0.0
# 4       1.8   45      男           20    公司     7      无   无防盗装置     国产    0.0
# 5       1.8   40      男      已婚   20    公司     7      有   无防盗装置     国产    0.0
# 6       1.8   54      男      已婚   20    公司     6      无   无防盗装置     国产    0.0
# 7       1.8   54      男      已婚   20    公司     6      有   无防盗装置     进口    0.0
# 8       1.8    0      男      已婚   20    政府     6      无   无防盗装置     国产    0.0
# 9       2.0    0      男      已婚   20    公司     6      有   无防盗装置     进口  288.0
# 10      1.8    0      男      已婚   20    公司     6      有   无防盗装置     国产    0.0
# ...

# %% [markdown]
# #### 查看各字段数据类型_索引范围_各类型字段数量_文件大小：

# %%
# ?df.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4233 entries, 0 to 4232
# Data columns (total 11 columns):
# EngSize    4233 non-null float64
# Age        4233 non-null int64
# Gender     4233 non-null object
# Marital    4233 non-null object
# exp        4233 non-null int64
# Owner      4233 non-null object
# vAge       4233 non-null int64
# Garage     4233 non-null object
# AntiTFD    4233 non-null object
# import     4233 non-null object
# Loss       4233 non-null float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 363.9+ KB

# %% [markdown]
# #### 查看准确内存使用量

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4233 entries, 0 to 4232
# Data columns (total 11 columns):
# EngSize    4233 non-null float64
# Age        4233 non-null int64
# Gender     4233 non-null object
# Marital    4233 non-null object
# exp        4233 non-null int64
# Owner      4233 non-null object
# vAge       4233 non-null int64
# Garage     4233 non-null object
# AntiTFD    4233 non-null object
# import     4233 non-null object
# Loss       4233 non-null float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 2.3 MB

# %% [markdown]
# #### 只查看各字段数据类型：

# %%
df.dtypes
# Out:
# EngSize    float64
# Age          int64
# Gender      object
# Marital     object
# exp          int64
# Owner       object
# vAge         int64
# Garage      object
# AntiTFD     object
# import      object
# Loss       float64
# dtype: object

# %% [markdown]
# #### 只查看所有字段名：

# %%
df.columns
# Out:
# Index(['EngSize', 'Age', 'Gender', 'Marital', 'exp', 'Owner', 'vAge', 'Garage',
#        'AntiTFD', 'import', 'Loss'],
#       dtype='object')

# %% [markdown]
# #### 查看总行数和总列数

# %%
df.shape
# Out:
# (4233, 11)

# %% [markdown]
# #### 查看各字段分布情况：默认数值型变量

# %%
df.describe()    # 当同时存在数值型和字符型变量时，默认只展示数值型描述统计
# Out:
#             EngSize           Age           exp          vAge          Loss
# count  16932.000000  16932.000000  16932.000000  16932.000000  16932.000000
# mean       1.814115     38.166430      5.948264      2.639440    586.827522
# std        0.335608      7.275541      4.535130      2.370798   2527.536714
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.600000     33.000000      3.000000      1.000000      0.000000
# 50%        1.800000     38.000000      5.000000      1.000000      0.000000
# 75%        1.800000     42.000000      8.000000      4.000000    320.000000
# max        3.000000     66.000000     20.000000     10.000000  60099.000000

# %% [markdown]
# #### 查看各字段分布情况：同时展示数值型和字符型变量

# %%
df.describe(include='all')
# Out:
#              EngSize           Age Gender Marital           exp  Owner  \
# count   16932.000000  16932.000000  16932   16932  16932.000000  16932
# unique           NaN           NaN      3       3           NaN      4
# top              NaN           NaN      男      已婚           NaN     私人
# freq             NaN           NaN  15095   16108           NaN  12104
# mean        1.814115     38.166430    NaN     NaN      5.948264    NaN
# std         0.335608      7.275541    NaN     NaN      4.535130    NaN
# min         0.000000      0.000000    NaN     NaN      0.000000    NaN
# 25%         1.600000     33.000000    NaN     NaN      3.000000    NaN
# 50%         1.800000     38.000000    NaN     NaN      5.000000    NaN
# 75%         1.800000     42.000000    NaN     NaN      8.000000    NaN
# max         3.000000     66.000000    NaN     NaN     20.000000    NaN
#
#                 vAge Garage AntiTFD import          Loss
# count   16932.000000  16932   16932  16932  16932.000000
# ...

# %% [markdown]
# #### 查看各字段分布情况：只展示数值型变量

# %%
df.describe(include=np.number)
# Out:
#             EngSize           Age           exp          vAge          Loss
# count  16932.000000  16932.000000  16932.000000  16932.000000  16932.000000
# mean       1.814115     38.166430      5.948264      2.639440    586.827522
# std        0.335608      7.275541      4.535130      2.370798   2527.536714
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.600000     33.000000      3.000000      1.000000      0.000000
# 50%        1.800000     38.000000      5.000000      1.000000      0.000000
# 75%        1.800000     42.000000      8.000000      4.000000    320.000000
# max        3.000000     66.000000     20.000000     10.000000  60099.000000

# %% [markdown]
# #### 查看各字段分布情况：只展示字符型或分类变量

# %% [markdown]
# 只展示字符型变量：

# %%
df.describe(include=np.object)
# Out:
#        Gender Marital  Owner Garage AntiTFD import
# count   16932   16932  16932  16932   16932  16932
# unique      3       3      4      3       3      3
# top         男      已婚     私人      有   无防盗装置     国产
# freq    15095   16108  12104  14180   13135  11876

# %% [markdown]
# 只展示分类变量：

# %%
df.describe(include='category')    # 当不存在categorical columns时，会报错
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9b5e28acf747> in <module>
# ----> 1 df.describe(include='category')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9945                     names.append(name)
#    9946
# -> 9947         d = pd.concat([x.reindex(names, copy=False) for x in ldesc], axis=1, sort=False)
#    9948         d.columns = data.columns.copy()
#    9949         return d
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ...

# %% [markdown]
# #### 查看各字段分布情况：只排除字符变量或数值变量

# %% [markdown]
# 排除字符型变量：

# %%
df.describe(exclude=np.object)
# Out:
#             EngSize           Age           exp          vAge          Loss
# count  16932.000000  16932.000000  16932.000000  16932.000000  16932.000000
# mean       1.814115     38.166430      5.948264      2.639440    586.827522
# std        0.335608      7.275541      4.535130      2.370798   2527.536714
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.600000     33.000000      3.000000      1.000000      0.000000
# 50%        1.800000     38.000000      5.000000      1.000000      0.000000
# 75%        1.800000     42.000000      8.000000      4.000000    320.000000
# max        3.000000     66.000000     20.000000     10.000000  60099.000000

# %% [markdown]
# 排除数值型变量：

# %%
df.describe(exclude=np.number)
# Out:
#        Gender Marital  Owner Garage AntiTFD import
# count   16932   16932  16932  16932   16932  16932
# unique      3       3      4      3       3      3
# top         男      已婚     私人      有   无防盗装置     国产
# freq    15095   16108  12104  14180   13135  11876

# %% [markdown]
# #### 查看指定字段各类别数量情况

# %% [markdown]
# 不含空值NaN：

# %%
df['Owner'].value_counts()
# Out:
# 私人    3023
# 公司     869
# 政府     336
#          5
# Name: Owner, dtype: int64

# %% [markdown]
# 包含空值NaN：

# %%
df['Owner'].value_counts(dropna=False)
# Out:
# 私人    12104
# 公司     3476
# 政府     1347
#           5
# Name: Owner, dtype: int64

# %% [markdown]
# 统计类别占比：

# %%
df['Owner'].value_counts(normalize=True)
# Out:
# 私人    0.714859
# 公司    0.205292
# 政府    0.079554
#       0.000295
# Name: Owner, dtype: float64

# %% [markdown]
# #### 透视表：

# %%
import numpy as np

tb = df.pivot_table(
    index=['Owner','Marital','Gender'],
    columns=['import'],
    values=['Age', 'Loss'],
    aggfunc={'Age': np.mean,'Loss': [min, max, np.mean, np.sum, 'count', np.std]},
    fill_value='-')
tb
# Out:
#                           Age                    Loss                   \
#                          mean                   count              max
# import                              国产       进口          国产    进口
# Owner Marital Gender
#       已婚      男             -     48.8        -     -     5     -    -
# 公司            男             -     46.5       56     -     4     1    -
#       已婚                    -       43        -     -     1     -    -
#               女             -     39.5  36.5263     -   128    76    -
#               男       48.3333  38.5916  37.9826     3  2157   975  240
#       未婚      男             -  28.3678  29.4545     -    87    44    -
# 政府    已婚                    -        -     46.5     -     -     2    -
#               女             -  35.7143        -     -    28     -    -
#               男             -  37.0346  36.2314     -   895   350    -
#       未婚      男             -  27.0667  24.6667     -    60    12    -
# ...

# %%
# ?df.pivot_table

# %%
# ?np.count_nonzero
