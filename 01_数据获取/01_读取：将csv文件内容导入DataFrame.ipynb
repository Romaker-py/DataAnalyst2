# %%
import pandas as pd

df = pd.read_csv(r'D:\Python\auto_ins.csv',encoding='gb18030')
df
# Out:
#       EngSize   Age Gender Marital   exp Owner  vAge Garage AntiTFD import  \
# 0         2.0  56.0      男     NaN  20.0    公司  10.0      有   有防盗装置     进口
# 1         1.8  41.0      男     NaN  20.0    公司   9.0      有   无防盗装置     国产
# 2         2.0  44.0      男     NaN  20.0    公司   8.0      有   有防盗装置     国产
# 3         1.6  56.0      男     NaN  20.0    公司   7.0      有   有防盗装置     国产
# 4         1.8  45.0      男     NaN  20.0    公司   7.0      无   无防盗装置     国产
# ...       ...   ...    ...     ...   ...   ...   ...    ...     ...    ...
# 4228      1.8  22.0      女      未婚   0.0    私人   1.0      有   有防盗装置     国产
# 4229      2.5  22.0      男      未婚   0.0    私人   1.0      有   无防盗装置     进口
# 4230      1.8  21.0      男      未婚   0.0    私人   1.0      有   无防盗装置     国产
# 4231      1.8  21.0      女      未婚   0.0    私人   1.0      有   无防盗装置     进口
# 4232      2.4  21.0      女      未婚   0.0    私人   1.0      有   无防盗装置     进口
#
#         Loss
# 0        0.0
# 1        0.0
# 2        0.0
# ...

# %% [markdown]
# 注意：默认csv第一行为字段名称，默认字段分隔符为,逗号

# %%
# ?pd.read_csv

# %% [markdown]
# #### 只导入前2000行

# %%
df_2000 = pd.read_csv(r'D:\Python\auto_ins.csv',encoding='gb2312',nrows=2000)
df_2000
# Out:
#       EngSize   Age Gender Marital   exp Owner  vAge Garage AntiTFD import  \
# 0         2.0  56.0      男     NaN  20.0    公司  10.0      有   有防盗装置     进口
# 1         1.8  41.0      男     NaN  20.0    公司   9.0      有   无防盗装置     国产
# 2         2.0  44.0      男     NaN  20.0    公司   8.0      有   有防盗装置     国产
# 3         1.6  56.0      男     NaN  20.0    公司   7.0      有   有防盗装置     国产
# 4         1.8  45.0      男     NaN  20.0    公司   7.0      无   无防盗装置     国产
# ...       ...   ...    ...     ...   ...   ...   ...    ...     ...    ...
# 1995      1.8  46.0      男      已婚   5.0    公司   1.0      有   有防盗装置     国产
# 1996      1.8  45.0      男      已婚   5.0    私人   1.0      有   无防盗装置     国产
# 1997      1.8  45.0      男      已婚   5.0    私人   1.0      有   无防盗装置     国产
# 1998      1.8  45.0      男      已婚   5.0    私人   1.0      有   无防盗装置     国产
# 1999      2.0  44.0      男      已婚   5.0    私人   1.0      有   无防盗装置     进口
#
#         Loss
# 0        0.0
# 1        0.0
# 2        0.0
# ...

# %% [markdown]
# #### 把指定列导入为日期格式

# %%
df_date = pd.read_csv(r'D:\Python\auto_ins.csv',parse_dates=['date','birthday'],encoding='gb2312',nrows=2000)
df_date
